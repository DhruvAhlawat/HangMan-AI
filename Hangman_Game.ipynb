# %% [markdown]
# ## Hangman game implementation. from the dictionary of words.

# %%
import random 
import pickle

# %%
def getWordsSize():
    text_file = open("words_250000_train.txt","r"); 
    wordsList = text_file.read().splitlines()[200000:]; 
    text_file.close(); 
    s = [0]*30; 
    for word in wordsList:
        s[len(word)] += 1; 
    return [(i, n) for (i,n) in enumerate(s)]; 

# getWordsSize()

# %%
class HangmanGame: #any object of this class can run the hangman game.
    def __init__(self, testingWords = None, curWordIndex = 0) -> None:
        print("initializing game engine"); 
        self.wordsList = testingWords; 
        if(self.wordsList is None):
            text_file = open("testWordsList.txt","r"); 
            self.wordsList = text_file.read().splitlines(); 
            text_file.close(); 
            random.shuffle(self.wordsList); #shuffle the words list so that we can get a random word each time.
        self.currentWordIndex = curWordIndex; # Index of the current word being used in the game
        print("initialization complete, total words available : ", len(self.wordsList)); 

    #so what we will output will just be the word, and keep count of guesses left ourself.

    def InputPlay(self, *args):
        guess = input("Guess a letter: "); 
        return guess; 


    def play(self, parentSolver = None, verbose = 2, tries_left = 6):
        if(verbose >= 1):
            print("Starting a new round of Hangman"); 
        
        if(self.currentWordIndex >= len(self.wordsList)):
            return None; #signifies that all the games have ended. 
        curWord = self.wordsList[self.currentWordIndex]; 
        self.currentWordIndex += 1; 
        curWord = [x for x in curWord]; 
        hiddenWord = ['_' for x in curWord]; 
        charsGuessed = set(); 
        IncorrectGuesses = set(); CorrectGuesses = set();  
        while(tries_left > 0 and hiddenWord != curWord): 
            if(verbose >= 1):
                print(" ".join(hiddenWord));  
            if(parentSolver is None):
                guess = self.InputPlay(hiddenWord,charsGuessed); #,IncorrectGuesses,CorrectGuesses); 
            else:
                guess = parentSolver.Solve(hiddenWord,charsGuessed, verbose = verbose); #,IncorrectGuesses,CorrectGuesses, verbose = verbose); 
            if(guess in charsGuessed):
                raise Exception("You already guessed the letter " + guess, "for : ", " ".join(hiddenWord)); 
            
            charsGuessed.add(guess); 
            if(guess in curWord and guess not in CorrectGuesses):
                CorrectGuesses.add(guess); 
                for i in range(len(curWord)):
                    if(curWord[i] == guess):
                        hiddenWord[i] = guess; 
            else:
                IncorrectGuesses.add(guess); 
                tries_left -= 1; 
                if(verbose == 2):
                    print("Incorrect guess. You have " + str(tries_left) + " tries left."); 
        if(tries_left == 0):
            if(verbose == 2):
                print("You lose. The word was " + " ".join(curWord)); 
            return (False, charsGuessed, IncorrectGuesses, ''.join(hiddenWord)); 
        else:
            if(verbose == 2):
                print("You win! The word is " + " ".join(curWord)); 
            return (True, charsGuessed, IncorrectGuesses, ''.join(hiddenWord)); 

        #then we can return some of the statistics of this game.

# %%
dictNgram = [0]*10; 
for i in range(2,10):
    with open('dict' + str(i) + 'gram.pickle', 'rb') as handle:
        dictNgram[i] = pickle.load(handle)

# %%
class NgramSolver:
    def __init__(self):
        self.guessedChars = set(); 
        return

    def Solve(self, hiddenWord, charsGuessed,verbose=0,version=4):
        return self.SolveN(hiddenWord, charsGuessed, verbose = verbose, n = version)
        
    def SolveN(self, word, charsGuessed, n = 5, verbose = 0, lowered = False): #3gram. 
        #now have to use 2-gram analysis to guess the next letter. 
        #we will use the 2-gram analysis from the training set.
        if(len(word) == 1 or n == 1): #if the size is only 1.
            for c in ['a','e','i','o','u','y']:
                if(c not in charsGuessed):
                    return c; 
        if(len(word) <= n and n != 2):
            return self.SolveN(word, charsGuessed, n = (n-1), lowered=True); 
        hiddenWord = ''.join(word); 
        if(not lowered):
            hcnt = hiddenWord.count('_');
            if(hcnt <= 2 and len(hiddenWord) >= 9 and (n < 7)):
                return self.SolveN(hiddenWord, charsGuessed, n = 7);
            if(hcnt <= 2 and len(hiddenWord) >= 7 and (n < 6)):
                return self.SolveN(hiddenWord, charsGuessed, n = 6); #we increase an n in this case.
            elif(hcnt/len(hiddenWord) <= 0.5 and (n < 5)):
                #print("going to 5 because current n is ", n); 
                return self.SolveN(hiddenWord, charsGuessed, n = 5); 
        hiddenWord = '^' + hiddenWord + '$';  #maybe we can remove this step?.
        if(hiddenWord[1:-1] == '_'*(len(hiddenWord)-2)):
        # if(hiddenWord == '_'*len(hiddenWord)):
            for c in ['a','e','i','o','u','y']:
                if(c not in charsGuessed):
                    return c; 
        
        #now we will move forward with 3 gram analysis of the result.
        freq = {};
        # freqVec = []
        # for i in range(len(hiddenWord)):
        #     freqVec.append({}); #an empty dictionary. 
        #considerCnt = [0]*len(hiddenWord); 
        for i in range(0,len(hiddenWord)-n+1):
            #starting our ngram analysis.
            curCheck = hiddenWord[i:i+n]; 
            #then we should consider the first 3 letters.
            # print(curCheck)
            if('_' not in curCheck):
                continue; #all are guessed.
            if(curCheck == '_'*n):
                continue; #all are blank here. 
            
            def checkFurther(curToCheck, pos, consts):
                if(pos >= len(curToCheck)):
                    #then we just update the frequencies. 
                    # print("checking", curToCheck);
                    if(curToCheck in dictNgram[n]):
                        # print("checked ", curToCheck); 
                        for (index,char) in enumerate(curToCheck):
                            if(char != '^' and char != '$'):                            
                                if(char in charsGuessed):
                                    continue #no need to update it's frequency.
                                if(char not in freq):
                                    freq[char] = 0; 
                                # if(char not in freqVec[i + index]):
                                #     freqVec[i + index][char] = 0;
                                # freqVec[i+index][char] += dictNgram[n][curToCheck];
                                freq[char] += (26**(consts-1))*dictNgram[n][curToCheck]; #multiplying this by consts to provide more weight.
                                #freq[char] += dict5gram[curToCheck]; #original case.
                    return; 
                if(curToCheck[pos] != '_'):
                    return checkFurther(curToCheck, pos + 1,consts + 1); #just check the next one as this one is already filled.
                else:
                    for c in range(ord('a'), ord('z') + 1):
                        if(chr(c) in charsGuessed):
                            continue; #this character has already been guessed.
                        checkFurther(curToCheck[:pos] + chr(c) + curToCheck[pos + 1:], pos + 1, consts); #removing the '_' from there.
                return; 
            checkFurther(curCheck, 0, 0); 

        #now we have the frequency possibilities of each character, and just need to predict the most likely one.
        
        if(len(freq) == 0):
            if(n == 2):
                raise Exception("No frequency found for n = 2, I wonder how ", hiddenWord, " is possible."); 

            return self.SolveN(hiddenWord, charsGuessed, n = n-1, lowered=True);
        charToGuess = max(freq, key = lambda x: freq[x]);   
        #self.guessedChars.add(charToGuess); #maybe not required.
        if(verbose >= 1):
            print("Guessing character ", charToGuess, " with frequency ", freq[charToGuess])
        
        return charToGuess;

# %%
solver = NgramSolver();
solver.Solve(['b','_','_','k'], set(['b','k']), verbose = 2)
# Out:
# 'a'

# %%
text_file = open("testWordsList.txt","r"); 
wordsList = text_file.read().splitlines(); 
text_file.close(); 
random.shuffle(wordsList);

# %%
failedStrings = []
successStrings = []
def Evaluate(curSolver, verbose = 0, limits = 1000):
    incorrectChars = 0; cnt = 0; 
    game = HangmanGame(curWordIndex=0, testingWords=wordsList); #initializes it with all the words of the game. 
    correctlyDone = 0; 
    squaredIncorrect = 0; totalCorrectGuesses = 0; 
    extremelyBad = 0; 
    curSolverObj = curSolver(); 
    while(game.currentWordIndex < limits):
    #while(game.currentWordIndex < 1000):
        if(verbose >= 1):
            print("playing game ", cnt, " with s = " ,game.wordsList[game.currentWordIndex], end = ", status? = "); 
        (didWin,totalGuesses,IncorrectGuesses, finalString) = game.play(parentSolver=curSolverObj, verbose = 0, tries_left=6); 
        curIncorrect = len(IncorrectGuesses); 
        # squaredIncorrect += curIncorrect**2; 
        incorrectChars += curIncorrect;  
        if(didWin):
            correctlyDone += 1; 
            successStrings.append(finalString)
            print("Won at ", finalString, end = " "); 
        else:
            failedStrings.append(finalString)
            print("Lost at ",finalString , end = " "); 
        if(curIncorrect >= 20):
            extremelyBad += 1; 
        cnt += 1; 
        print(" wins till now ", correctlyDone, " out of ", cnt); 
    return (incorrectChars/cnt, correctlyDone/cnt, failedStrings, successStrings);

# %%
stored = Evaluate(NgramSolver, verbose = 2, limits=1000)
# Out:
# initializing game engine
# initialization complete, total words available :  45460
# playing game  0  with s =  windbroken, status? = Lost at  __nd_ro_en  wins till now  0  out of  1
# playing game  1  with s =  turnverein, status? = Won at  turnverein  wins till now  1  out of  2
# playing game  2  with s =  aarika, status? = Lost at  aari_a  wins till now  1  out of  3
# playing game  3  with s =  umbrageousness, status? = Won at  umbrageousness  wins till now  2  out of  4
# playing game  4  with s =  sclerotioid, status? = Won at  sclerotioid  wins till now  3  out of  5
# playing game  5  with s =  stridor, status? = Lost at  _tri_or  wins till now  3  out of  6
# playing game  6  with s =  cohue, status? = Lost at  _o__e  wins till now  3  out of  7
# playing game  7  with s =  parrah, status? = Lost at  _arra_  wins till now  3  out of  8
# playing game  8  with s =  akeldama, status? = Lost at  a_eldama  wins till now  3  out of  9
# playing game  9  with s =  jiffy, status? = Lost at  _i___  wins till now  3  out of  10
# playing game  10  with s =  callainite, status? = Won at  callainite  wins till now  4  out of  11
# playing game  11  with s =  denaturalization, status? = Won at  denaturalization  wins till now  5  out of  12
# playing game  12  with s =  dunracked, status? = Won at  dunracked  wins till now  6  out of  13
# playing game  13  with s =  townhouse, status? = Won at  townhouse  wins till now  7  out of  14
# playing game  14  with s =  buccaned, status? = Lost at  ____aned  wins till now  7  out of  15
# playing game  15  with s =  aphorizes, status? = Won at  aphorizes  wins till now  8  out of  16
# playing game  16  with s =  postoral, status? = Won at  postoral  wins till now  9  out of  17
# playing game  17  with s =  unweighableness, status? = Won at  unweighableness  wins till now  10  out of  18
# playing game  18  with s =  gompers, status? = Lost at  _ompers  wins till now  10  out of  19
# playing game  19  with s =  taroks, status? = Lost at  tar___  wins till now  10  out of  20
# playing game  20  with s =  dikdik, status? = Lost at  _i__i_  wins till now  10  out of  21
# playing game  21  with s =  corsac, status? = Lost at  _orsa_  wins till now  10  out of  22
# playing game  22  with s =  enumerating, status? = Won at  enumerating  wins till now  11  out of  23
# playing game  23  with s =  nonvenously, status? = Lost at  non_eno_s__  wins till now  11  out of  24
# playing game  24  with s =  dilleniaceous, status? = Won at  dilleniaceous  wins till now  12  out of  25
# playing game  25  with s =  pseudomaniac, status? = Won at  pseudomaniac  wins till now  13  out of  26
# playing game  26  with s =  isocaproic, status? = Won at  isocaproic  wins till now  14  out of  27
# playing game  27  with s =  geocoronium, status? = Won at  geocoronium  wins till now  15  out of  28
# playing game  28  with s =  pussyfootism, status? = Lost at  __ss__ootism  wins till now  15  out of  29
# playing game  29  with s =  stockblind, status? = Lost at  stock__in_  wins till now  15  out of  30
# playing game  30  with s =  promote, status? = Won at  promote  wins till now  16  out of  31
# playing game  31  with s =  elenge, status? = Lost at  e_en_e  wins till now  16  out of  32
# playing game  32  with s =  pandrop, status? = Won at  pandrop  wins till now  17  out of  33
# playing game  33  with s =  smoothbore, status? = Lost at  smooth_ore  wins till now  17  out of  34
# playing game  34  with s =  galabias, status? = Lost at  gala_ia_  wins till now  17  out of  35
# playing game  35  with s =  embowel, status? = Lost at  e____el  wins till now  17  out of  36
# playing game  36  with s =  ailments, status? = Won at  ailments  wins till now  18  out of  37
# playing game  37  with s =  should, status? = Lost at  sho___  wins till now  18  out of  38
# playing game  38  with s =  jul, status? = Lost at  _u_  wins till now  18  out of  39
# playing game  39  with s =  keelby, status? = Lost at  _eelb_  wins till now  18  out of  40
# playing game  40  with s =  ragucci, status? = Lost at  ra__cci  wins till now  18  out of  41
# playing game  41  with s =  locksmith, status? = Won at  locksmith  wins till now  19  out of  42
# playing game  42  with s =  yarding, status? = Lost at  _ar____  wins till now  19  out of  43
# playing game  43  with s =  bugproof, status? = Lost at  ___proof  wins till now  19  out of  44
# playing game  44  with s =  diaxone, status? = Lost at  dia___e  wins till now  19  out of  45
# playing game  45  with s =  relaster, status? = Won at  relaster  wins till now  20  out of  46
# playing game  46  with s =  caricology, status? = Won at  caricology  wins till now  21  out of  47
# playing game  47  with s =  justifications, status? = Won at  justifications  wins till now  22  out of  48
# playing game  48  with s =  obsequence, status? = Lost at  ___e__ence  wins till now  22  out of  49
# playing game  49  with s =  toddyman, status? = Lost at  to___man  wins till now  22  out of  50
# playing game  50  with s =  jugsful, status? = Lost at  _u_sful  wins till now  22  out of  51
# playing game  51  with s =  sufferance, status? = Lost at  ____erance  wins till now  22  out of  52
# playing game  52  with s =  schoolma, status? = Won at  schoolma  wins till now  23  out of  53
# playing game  53  with s =  adopting, status? = Lost at  a___ting  wins till now  23  out of  54
# playing game  54  with s =  timerent, status? = Lost at  t__erent  wins till now  23  out of  55
# playing game  55  with s =  spending, status? = Won at  spending  wins till now  24  out of  56
# playing game  56  with s =  pseudoenglish, status? = Won at  pseudoenglish  wins till now  25  out of  57
# playing game  57  with s =  zannini, status? = Lost at  _annini  wins till now  25  out of  58
# playing game  58  with s =  postlarval, status? = Lost at  __s_lar_al  wins till now  25  out of  59
# playing game  59  with s =  sequestral, status? = Won at  sequestral  wins till now  26  out of  60
# playing game  60  with s =  jinjili, status? = Lost at  _in_i_i  wins till now  26  out of  61
# playing game  61  with s =  tallbodied, status? = Won at  tallbodied  wins till now  27  out of  62
# playing game  62  with s =  premodifies, status? = Won at  premodifies  wins till now  28  out of  63
# playing game  63  with s =  preguided, status? = Won at  preguided  wins till now  29  out of  64
# playing game  64  with s =  parceltying, status? = Won at  parceltying  wins till now  30  out of  65
# playing game  65  with s =  cacophonical, status? = Won at  cacophonical  wins till now  31  out of  66
# playing game  66  with s =  birdt, status? = Lost at  _ir__  wins till now  31  out of  67
# playing game  67  with s =  taylorsville, status? = Won at  taylorsville  wins till now  32  out of  68
# playing game  68  with s =  clochards, status? = Won at  clochards  wins till now  33  out of  69
# playing game  69  with s =  octodecillion, status? = Won at  octodecillion  wins till now  34  out of  70
# playing game  70  with s =  ambosexous, status? = Lost at  am_ose_ous  wins till now  34  out of  71
# playing game  71  with s =  wellengineered, status? = Won at  wellengineered  wins till now  35  out of  72
# playing game  72  with s =  fibrous, status? = Won at  fibrous  wins till now  36  out of  73
# playing game  73  with s =  subgalea, status? = Lost at  sub_alea  wins till now  36  out of  74
# playing game  74  with s =  cheesewood, status? = Lost at  cheese_oo_  wins till now  36  out of  75
# playing game  75  with s =  slumberer, status? = Lost at  _____erer  wins till now  36  out of  76
# playing game  76  with s =  consulting, status? = Won at  consulting  wins till now  37  out of  77
# playing game  77  with s =  boatsteerer, status? = Won at  boatsteerer  wins till now  38  out of  78
# playing game  78  with s =  palfreyed, status? = Lost at  _al_reyed  wins till now  38  out of  79
# playing game  79  with s =  mimeographs, status? = Won at  mimeographs  wins till now  39  out of  80
# playing game  80  with s =  dowsets, status? = Won at  dowsets  wins till now  40  out of  81
# playing game  81  with s =  sauro, status? = Lost at  saur_  wins till now  40  out of  82
# playing game  82  with s =  goslet, status? = Lost at  __s_et  wins till now  40  out of  83
# playing game  83  with s =  ketoxime, status? = Lost at  _et__i_e  wins till now  40  out of  84
# playing game  84  with s =  capitare, status? = Won at  capitare  wins till now  41  out of  85
# playing game  85  with s =  fidgetiness, status? = Lost at  _i__etiness  wins till now  41  out of  86
# playing game  86  with s =  endicott, status? = Lost at  en_ic_tt  wins till now  41  out of  87
# playing game  87  with s =  mouldier, status? = Won at  mouldier  wins till now  42  out of  88
# playing game  88  with s =  unanticipating, status? = Won at  unanticipating  wins till now  43  out of  89
# playing game  89  with s =  spoilation, status? = Won at  spoilation  wins till now  44  out of  90
# playing game  90  with s =  unblanketed, status? = Won at  unblanketed  wins till now  45  out of  91
# playing game  91  with s =  cerelia, status? = Won at  cerelia  wins till now  46  out of  92
# playing game  92  with s =  chichimecan, status? = Won at  chichimecan  wins till now  47  out of  93
# playing game  93  with s =  aerical, status? = Won at  aerical  wins till now  48  out of  94
# playing game  94  with s =  deadlihead, status? = Won at  deadlihead  wins till now  49  out of  95
# playing game  95  with s =  myoparalysis, status? = Won at  myoparalysis  wins till now  50  out of  96
# playing game  96  with s =  chromonematic, status? = Won at  chromonematic  wins till now  51  out of  97
# playing game  97  with s =  hypoionian, status? = Won at  hypoionian  wins till now  52  out of  98
# playing game  98  with s =  flocculate, status? = Won at  flocculate  wins till now  53  out of  99
# playing game  99  with s =  ieyasu, status? = Lost at  _e_as_  wins till now  53  out of  100
# playing game  100  with s =  geneologically, status? = Won at  geneologically  wins till now  54  out of  101
# playing game  101  with s =  pantophobia, status? = Won at  pantophobia  wins till now  55  out of  102
# playing game  102  with s =  msphar, status? = Lost at  ____ar  wins till now  55  out of  103
# playing game  103  with s =  standerwort, status? = Won at  standerwort  wins till now  56  out of  104
# playing game  104  with s =  selfdisclosing, status? = Won at  selfdisclosing  wins till now  57  out of  105
# playing game  105  with s =  stoveless, status? = Won at  stoveless  wins till now  58  out of  106
# playing game  106  with s =  halfguinea, status? = Lost at  half__i__a  wins till now  58  out of  107
# playing game  107  with s =  thermophosphorescence, status? = Won at  thermophosphorescence  wins till now  59  out of  108
# playing game  108  with s =  seepproof, status? = Won at  seepproof  wins till now  60  out of  109
# playing game  109  with s =  hammocks, status? = Lost at  _a_____s  wins till now  60  out of  110
# playing game  110  with s =  thwacks, status? = Lost at  ___a___  wins till now  60  out of  111
# playing game  111  with s =  duettists, status? = Won at  duettists  wins till now  61  out of  112
# playing game  112  with s =  wheedles, status? = Won at  wheedles  wins till now  62  out of  113
# playing game  113  with s =  bigname, status? = Lost at  _igname  wins till now  62  out of  114
# playing game  114  with s =  nonpersistently, status? = Won at  nonpersistently  wins till now  63  out of  115
# playing game  115  with s =  wycliffe, status? = Lost at  ___li__e  wins till now  63  out of  116
# playing game  116  with s =  advice, status? = Lost at  ad_i_e  wins till now  63  out of  117
# playing game  117  with s =  kniggr, status? = Lost at  _ni__r  wins till now  63  out of  118
# playing game  118  with s =  synarthrosis, status? = Won at  synarthrosis  wins till now  64  out of  119
# playing game  119  with s =  unawared, status? = Won at  unawared  wins till now  65  out of  120
# playing game  120  with s =  schoenobatic, status? = Won at  schoenobatic  wins till now  66  out of  121
# playing game  121  with s =  hymenophyllaceous, status? = Won at  hymenophyllaceous  wins till now  67  out of  122
# playing game  122  with s =  sporiferous, status? = Won at  sporiferous  wins till now  68  out of  123
# playing game  123  with s =  hsingborg, status? = Lost at  _singborg  wins till now  68  out of  124
# playing game  124  with s =  underspecies, status? = Won at  underspecies  wins till now  69  out of  125
# playing game  125  with s =  huesman, status? = Lost at  __esman  wins till now  69  out of  126
# playing game  126  with s =  myographs, status? = Won at  myographs  wins till now  70  out of  127
# playing game  127  with s =  camerlingos, status? = Won at  camerlingos  wins till now  71  out of  128
# playing game  128  with s =  bluets, status? = Won at  bluets  wins till now  72  out of  129
# playing game  129  with s =  furriery, status? = Lost at  _urrier_  wins till now  72  out of  130
# playing game  130  with s =  julienne, status? = Won at  julienne  wins till now  73  out of  131
# playing game  131  with s =  tiepolo, status? = Lost at  tie_olo  wins till now  73  out of  132
# playing game  132  with s =  addressable, status? = Won at  addressable  wins till now  74  out of  133
# playing game  133  with s =  countercheer, status? = Won at  countercheer  wins till now  75  out of  134
# playing game  134  with s =  treves, status? = Lost at  tre_es  wins till now  75  out of  135
# playing game  135  with s =  nothingarian, status? = Won at  nothingarian  wins till now  76  out of  136
# playing game  136  with s =  swish, status? = Lost at  s_ish  wins till now  76  out of  137
# playing game  137  with s =  nonatheistical, status? = Won at  nonatheistical  wins till now  77  out of  138
# playing game  138  with s =  feh, status? = Lost at  _e_  wins till now  77  out of  139
# playing game  139  with s =  esthesises, status? = Won at  esthesises  wins till now  78  out of  140
# playing game  140  with s =  nutmeg, status? = Lost at  n_t_e_  wins till now  78  out of  141
# playing game  141  with s =  antanagoge, status? = Lost at  antanagog_  wins till now  78  out of  142
# playing game  142  with s =  requisitioner, status? = Won at  requisitioner  wins till now  79  out of  143
# playing game  143  with s =  dormitories, status? = Won at  dormitories  wins till now  80  out of  144
# playing game  144  with s =  wh, status? = Lost at  __  wins till now  80  out of  145
# playing game  145  with s =  limu, status? = Lost at  _im_  wins till now  80  out of  146
# playing game  146  with s =  subspecialist, status? = Won at  subspecialist  wins till now  81  out of  147
# playing game  147  with s =  thimblefuls, status? = Lost at  t_i__lefuls  wins till now  81  out of  148
# playing game  148  with s =  sloshed, status? = Lost at  sl_shed  wins till now  81  out of  149
# playing game  149  with s =  counteroffensives, status? = Won at  counteroffensives  wins till now  82  out of  150
# playing game  150  with s =  altrices, status? = Won at  altrices  wins till now  83  out of  151
# playing game  151  with s =  bemurmured, status? = Lost at  _emurmured  wins till now  83  out of  152
# playing game  152  with s =  lowlands, status? = Won at  lowlands  wins till now  84  out of  153
# playing game  153  with s =  longlocked, status? = Lost at  longlo__ed  wins till now  84  out of  154
# playing game  154  with s =  wellscorched, status? = Won at  wellscorched  wins till now  85  out of  155
# playing game  155  with s =  zygotomere, status? = Lost at  ____t__ere  wins till now  85  out of  156
# playing game  156  with s =  minaciousness, status? = Won at  minaciousness  wins till now  86  out of  157
# playing game  157  with s =  dedie, status? = Won at  dedie  wins till now  87  out of  158
# playing game  158  with s =  motorically, status? = Won at  motorically  wins till now  88  out of  159
# playing game  159  with s =  ethylenes, status? = Won at  ethylenes  wins till now  89  out of  160
# playing game  160  with s =  testingly, status? = Won at  testingly  wins till now  90  out of  161
# playing game  161  with s =  nonprofessorially, status? = Won at  nonprofessorially  wins till now  91  out of  162
# playing game  162  with s =  unmeshes, status? = Won at  unmeshes  wins till now  92  out of  163
# playing game  163  with s =  cephalodiscida, status? = Lost at  cephalo_isci_a  wins till now  92  out of  164
# playing game  164  with s =  heart, status? = Won at  heart  wins till now  93  out of  165
# playing game  165  with s =  endwise, status? = Won at  endwise  wins till now  94  out of  166
# playing game  166  with s =  contumacy, status? = Won at  contumacy  wins till now  95  out of  167
# playing game  167  with s =  boulevards, status? = Lost at  ____e_ar__  wins till now  95  out of  168
# playing game  168  with s =  televiews, status? = Lost at  tele__e_s  wins till now  95  out of  169
# playing game  169  with s =  subarration, status? = Won at  subarration  wins till now  96  out of  170
# playing game  170  with s =  impetrative, status? = Won at  impetrative  wins till now  97  out of  171
# playing game  171  with s =  goossens, status? = Lost at  _oossens  wins till now  97  out of  172
# playing game  172  with s =  fernowl, status? = Lost at  _er____  wins till now  97  out of  173
# playing game  173  with s =  translatress, status? = Won at  translatress  wins till now  98  out of  174
# playing game  174  with s =  crassness, status? = Won at  crassness  wins till now  99  out of  175
# playing game  175  with s =  dfms, status? = Lost at  ____  wins till now  99  out of  176
# playing game  176  with s =  harshfeatured, status? = Lost at  _ar__featured  wins till now  99  out of  177
# playing game  177  with s =  repledged, status? = Won at  repledged  wins till now  100  out of  178
# playing game  178  with s =  bremen, status? = Lost at  _remen  wins till now  100  out of  179
# playing game  179  with s =  brawled, status? = Won at  brawled  wins till now  101  out of  180
# playing game  180  with s =  scaife, status? = Lost at  s_ai_e  wins till now  101  out of  181
# playing game  181  with s =  chabuks, status? = Lost at  __a_u_s  wins till now  101  out of  182
# playing game  182  with s =  mayapple, status? = Lost at  _a_apple  wins till now  101  out of  183
# playing game  183  with s =  outfoxes, status? = Lost at  __t___es  wins till now  101  out of  184
# playing game  184  with s =  underfacing, status? = Lost at  under_acing  wins till now  101  out of  185
# playing game  185  with s =  obtruding, status? = Won at  obtruding  wins till now  102  out of  186
# playing game  186  with s =  motherfucker, status? = Lost at  mother____er  wins till now  102  out of  187
# playing game  187  with s =  degeneration, status? = Won at  degeneration  wins till now  103  out of  188
# playing game  188  with s =  summonsproof, status? = Lost at  ____on_proof  wins till now  103  out of  189
# playing game  189  with s =  tabbarea, status? = Lost at  ta__ar_a  wins till now  103  out of  190
# playing game  190  with s =  lopez, status? = Lost at  l__e_  wins till now  103  out of  191
# playing game  191  with s =  bluey, status? = Lost at  blue_  wins till now  103  out of  192
# playing game  192  with s =  shamoyed, status? = Lost at  s_a___ed  wins till now  103  out of  193
# playing game  193  with s =  bronzed, status? = Lost at  _r_n_ed  wins till now  103  out of  194
# playing game  194  with s =  twistification, status? = Won at  twistification  wins till now  104  out of  195
# playing game  195  with s =  blackbordered, status? = Won at  blackbordered  wins till now  105  out of  196
# playing game  196  with s =  revealers, status? = Won at  revealers  wins till now  106  out of  197
# playing game  197  with s =  inkdropping, status? = Lost at  inkdr___ing  wins till now  106  out of  198
# playing game  198  with s =  outhowling, status? = Lost at  o_t_o_ling  wins till now  106  out of  199
# playing game  199  with s =  chickpea, status? = Lost at  chick_ea  wins till now  106  out of  200
# playing game  200  with s =  heavytailed, status? = Lost at  hea__tailed  wins till now  106  out of  201
# playing game  201  with s =  diversities, status? = Won at  diversities  wins till now  107  out of  202
# playing game  202  with s =  rassasy, status? = Lost at  rassas_  wins till now  107  out of  203
# playing game  203  with s =  prestraighten, status? = Won at  prestraighten  wins till now  108  out of  204
# playing game  204  with s =  sixfoil, status? = Won at  sixfoil  wins till now  109  out of  205
# playing game  205  with s =  alsine, status? = Lost at  al_ine  wins till now  109  out of  206
# playing game  206  with s =  sophy, status? = Lost at  _o___  wins till now  109  out of  207
# playing game  207  with s =  catalase, status? = Won at  catalase  wins till now  110  out of  208
# playing game  208  with s =  percussively, status? = Won at  percussively  wins till now  111  out of  209
# playing game  209  with s =  peppery, status? = Lost at  _e__ery  wins till now  111  out of  210
# playing game  210  with s =  juxtalittoral, status? = Won at  juxtalittoral  wins till now  112  out of  211
# playing game  211  with s =  secern, status? = Won at  secern  wins till now  113  out of  212
# playing game  212  with s =  clutchy, status? = Lost at  _lu____  wins till now  113  out of  213
# playing game  213  with s =  sourbreathed, status? = Won at  sourbreathed  wins till now  114  out of  214
# playing game  214  with s =  muscovite, status? = Lost at  m_s___ite  wins till now  114  out of  215
# playing game  215  with s =  cuvier, status? = Lost at  ___ier  wins till now  114  out of  216
# playing game  216  with s =  stelazine, status? = Won at  stelazine  wins till now  115  out of  217
# playing game  217  with s =  unrepetitiously, status? = Won at  unrepetitiously  wins till now  116  out of  218
# playing game  218  with s =  vouches, status? = Lost at  _____es  wins till now  116  out of  219
# playing game  219  with s =  misorganization, status? = Won at  misorganization  wins till now  117  out of  220
# playing game  220  with s =  plasterlike, status? = Won at  plasterlike  wins till now  118  out of  221
# playing game  221  with s =  evolutionists, status? = Won at  evolutionists  wins till now  119  out of  222
# playing game  222  with s =  dsn, status? = Lost at  ___  wins till now  119  out of  223
# playing game  223  with s =  osela, status? = Lost at  o_ela  wins till now  119  out of  224
# playing game  224  with s =  sublimational, status? = Won at  sublimational  wins till now  120  out of  225
# playing game  225  with s =  uroplania, status? = Lost at  _roplania  wins till now  120  out of  226
# playing game  226  with s =  chantry, status? = Lost at  __a__r_  wins till now  120  out of  227
# playing game  227  with s =  argan, status? = Won at  argan  wins till now  121  out of  228
# playing game  228  with s =  boatlowering, status? = Won at  boatlowering  wins till now  122  out of  229
# playing game  229  with s =  loxodromical, status? = Won at  loxodromical  wins till now  123  out of  230
# playing game  230  with s =  cynodictis, status? = Won at  cynodictis  wins till now  124  out of  231
# playing game  231  with s =  candystriped, status? = Won at  candystriped  wins till now  125  out of  232
# playing game  232  with s =  batyphone, status? = Lost at  _atyphone  wins till now  125  out of  233
# playing game  233  with s =  unreproving, status? = Lost at  _nre_r__ing  wins till now  125  out of  234
# playing game  234  with s =  biforin, status? = Lost at  _i__rin  wins till now  125  out of  235
# playing game  235  with s =  maziness, status? = Lost at  ma_in___  wins till now  125  out of  236
# playing game  236  with s =  anthers, status? = Won at  anthers  wins till now  126  out of  237
# playing game  237  with s =  deionizing, status? = Won at  deionizing  wins till now  127  out of  238
# playing game  238  with s =  colicystitis, status? = Won at  colicystitis  wins till now  128  out of  239
# playing game  239  with s =  perlites, status? = Won at  perlites  wins till now  129  out of  240
# playing game  240  with s =  undieted, status? = Lost at  _nd_eted  wins till now  129  out of  241
# playing game  241  with s =  undertutor, status? = Won at  undertutor  wins till now  130  out of  242
# playing game  242  with s =  agamist, status? = Lost at  agam___  wins till now  130  out of  243
# playing game  243  with s =  wat, status? = Lost at  _at  wins till now  130  out of  244
# playing game  244  with s =  wellbrawned, status? = Won at  wellbrawned  wins till now  131  out of  245
# playing game  245  with s =  hypersensitivity, status? = Won at  hypersensitivity  wins till now  132  out of  246
# playing game  246  with s =  fondly, status? = Lost at  _on_ly  wins till now  132  out of  247
# playing game  247  with s =  nf, status? = Lost at  __  wins till now  132  out of  248
# playing game  248  with s =  herrban, status? = Lost at  _err_an  wins till now  132  out of  249
# playing game  249  with s =  riggald, status? = Lost at  riggal_  wins till now  132  out of  250
# playing game  250  with s =  stolonic, status? = Lost at  _to_onic  wins till now  132  out of  251
# playing game  251  with s =  mineraloid, status? = Won at  mineraloid  wins till now  133  out of  252
# playing game  252  with s =  quasimunicipal, status? = Won at  quasimunicipal  wins till now  134  out of  253
# playing game  253  with s =  latirostres, status? = Won at  latirostres  wins till now  135  out of  254
# playing game  254  with s =  heteroproteose, status? = Won at  heteroproteose  wins till now  136  out of  255
# playing game  255  with s =  modif, status? = Lost at  _o_i_  wins till now  136  out of  256
# playing game  256  with s =  squadder, status? = Lost at  s__adder  wins till now  136  out of  257
# playing game  257  with s =  promiscuities, status? = Won at  promiscuities  wins till now  137  out of  258
# playing game  258  with s =  ortles, status? = Won at  ortles  wins till now  138  out of  259
# playing game  259  with s =  autocephalous, status? = Won at  autocephalous  wins till now  139  out of  260
# playing game  260  with s =  openspaced, status? = Won at  openspaced  wins till now  140  out of  261
# playing game  261  with s =  korff, status? = Lost at  _orff  wins till now  140  out of  262
# playing game  262  with s =  centres, status? = Won at  centres  wins till now  141  out of  263
# playing game  263  with s =  moniliaceous, status? = Won at  moniliaceous  wins till now  142  out of  264
# playing game  264  with s =  bached, status? = Lost at  bac___  wins till now  142  out of  265
# playing game  265  with s =  prebless, status? = Lost at  _re_less  wins till now  142  out of  266
# playing game  266  with s =  revolvingly, status? = Lost at  re_________  wins till now  142  out of  267
# playing game  267  with s =  cymbre, status? = Lost at  _____e  wins till now  142  out of  268
# playing game  268  with s =  unreadily, status? = Won at  unreadily  wins till now  143  out of  269
# playing game  269  with s =  sider, status? = Won at  sider  wins till now  144  out of  270
# playing game  270  with s =  engraven, status? = Won at  engraven  wins till now  145  out of  271
# playing game  271  with s =  carrolls, status? = Lost at  carro___  wins till now  145  out of  272
# playing game  272  with s =  scrapples, status? = Won at  scrapples  wins till now  146  out of  273
# playing game  273  with s =  trompes, status? = Lost at  tro__es  wins till now  146  out of  274
# playing game  274  with s =  screwstock, status? = Won at  screwstock  wins till now  147  out of  275
# playing game  275  with s =  preenumeration, status? = Won at  preenumeration  wins till now  148  out of  276
# playing game  276  with s =  chamacea, status? = Lost at  c_a_ac_a  wins till now  148  out of  277
# playing game  277  with s =  keelhaled, status? = Lost at  _ee__a_ed  wins till now  148  out of  278
# playing game  278  with s =  lanose, status? = Lost at  lan_s_  wins till now  148  out of  279
# playing game  279  with s =  hyperhedonia, status? = Lost at  h___rh__onia  wins till now  148  out of  280
# playing game  280  with s =  pussyfoot, status? = Won at  pussyfoot  wins till now  149  out of  281
# playing game  281  with s =  seclusionist, status? = Won at  seclusionist  wins till now  150  out of  282
# playing game  282  with s =  solvolyzing, status? = Lost at  s_l__l__ing  wins till now  150  out of  283
# playing game  283  with s =  hargreaves, status? = Lost at  _ar_rea_e_  wins till now  150  out of  284
# playing game  284  with s =  cynwyd, status? = Lost at  _y__y_  wins till now  150  out of  285
# playing game  285  with s =  exportability, status? = Won at  exportability  wins till now  151  out of  286
# playing game  286  with s =  sweeter, status? = Won at  sweeter  wins till now  152  out of  287
# playing game  287  with s =  mimbres, status? = Lost at  _i__res  wins till now  152  out of  288
# playing game  288  with s =  pigback, status? = Lost at  ____a__  wins till now  152  out of  289
# playing game  289  with s =  underbudde, status? = Lost at  under_udde  wins till now  152  out of  290
# playing game  290  with s =  stride, status? = Won at  stride  wins till now  153  out of  291
# playing game  291  with s =  mineralise, status? = Won at  mineralise  wins till now  154  out of  292
# playing game  292  with s =  overdependence, status? = Won at  overdependence  wins till now  155  out of  293
# playing game  293  with s =  streptoneura, status? = Won at  streptoneura  wins till now  156  out of  294
# playing game  294  with s =  gispin, status? = Lost at  _is_i_  wins till now  156  out of  295
# playing game  295  with s =  vives, status? = Lost at  _i_es  wins till now  156  out of  296
# playing game  296  with s =  linctus, status? = Lost at  _in___s  wins till now  156  out of  297
# playing game  297  with s =  radiosterilization, status? = Won at  radiosterilization  wins till now  157  out of  298
# playing game  298  with s =  aneurismal, status? = Won at  aneurismal  wins till now  158  out of  299
# playing game  299  with s =  oilcloth, status? = Lost at  _il_l___  wins till now  158  out of  300
# playing game  300  with s =  stampman, status? = Won at  stampman  wins till now  159  out of  301
# playing game  301  with s =  sulcatoareolate, status? = Won at  sulcatoareolate  wins till now  160  out of  302
# playing game  302  with s =  depew, status? = Lost at  de_e_  wins till now  160  out of  303
# playing game  303  with s =  bayley, status? = Lost at  ba_le_  wins till now  160  out of  304
# playing game  304  with s =  ingoting, status? = Lost at  ing_ting  wins till now  160  out of  305
# playing game  305  with s =  ebbie, status? = Lost at  e__ie  wins till now  160  out of  306
# playing game  306  with s =  diasporas, status? = Lost at  __asporas  wins till now  160  out of  307
# playing game  307  with s =  smoothify, status? = Lost at  smoothi__  wins till now  160  out of  308
# playing game  308  with s =  expositively, status? = Won at  expositively  wins till now  161  out of  309
# playing game  309  with s =  deul, status? = Lost at  de_l  wins till now  161  out of  310
# playing game  310  with s =  turacoverdin, status? = Won at  turacoverdin  wins till now  162  out of  311
# playing game  311  with s =  auditoria, status? = Won at  auditoria  wins till now  163  out of  312
# playing game  312  with s =  propolynesian, status? = Won at  propolynesian  wins till now  164  out of  313
# playing game  313  with s =  photopias, status? = Won at  photopias  wins till now  165  out of  314
# playing game  314  with s =  sawnoff, status? = Lost at  sa_n___  wins till now  165  out of  315
# playing game  315  with s =  schelling, status? = Lost at  ___elling  wins till now  165  out of  316
# playing game  316  with s =  thankworthily, status? = Won at  thankworthily  wins till now  166  out of  317
# playing game  317  with s =  quadrimum, status? = Lost at  quadri_u_  wins till now  166  out of  318
# playing game  318  with s =  mouseion, status? = Lost at  mo__eion  wins till now  166  out of  319
# playing game  319  with s =  intendencies, status? = Won at  intendencies  wins till now  167  out of  320
# playing game  320  with s =  embussed, status? = Lost at  e___ssed  wins till now  167  out of  321
# playing game  321  with s =  netts, status? = Lost at  ne__s  wins till now  167  out of  322
# playing game  322  with s =  interventricular, status? = Won at  interventricular  wins till now  168  out of  323
# playing game  323  with s =  warmheartedness, status? = Won at  warmheartedness  wins till now  169  out of  324
# playing game  324  with s =  turkeyfishes, status? = Won at  turkeyfishes  wins till now  170  out of  325
# playing game  325  with s =  alpieu, status? = Lost at  al_ie_  wins till now  170  out of  326
# playing game  326  with s =  crio, status? = Won at  crio  wins till now  171  out of  327
# playing game  327  with s =  vagarist, status? = Won at  vagarist  wins till now  172  out of  328
# playing game  328  with s =  pipes, status? = Lost at  _i_es  wins till now  172  out of  329
# playing game  329  with s =  vixens, status? = Lost at  ___ens  wins till now  172  out of  330
# playing game  330  with s =  jecorin, status? = Lost at  _e_orin  wins till now  172  out of  331
# playing game  331  with s =  pernyi, status? = Lost at  per__i  wins till now  172  out of  332
# playing game  332  with s =  holes, status? = Lost at  _oles  wins till now  172  out of  333
# playing game  333  with s =  marxistleninist, status? = Lost at  mar_ist__ninist  wins till now  172  out of  334
# playing game  334  with s =  wavecut, status? = Lost at  _a__c_t  wins till now  172  out of  335
# playing game  335  with s =  unnerved, status? = Won at  unnerved  wins till now  173  out of  336
# playing game  336  with s =  subhumid, status? = Lost at  sub_u_id  wins till now  173  out of  337
# playing game  337  with s =  triggerless, status? = Lost at  tri__erless  wins till now  173  out of  338
# playing game  338  with s =  randomish, status? = Won at  randomish  wins till now  174  out of  339
# playing game  339  with s =  repopulate, status? = Won at  repopulate  wins till now  175  out of  340
# playing game  340  with s =  gelsemin, status? = Won at  gelsemin  wins till now  176  out of  341
# playing game  341  with s =  superresponsible, status? = Won at  superresponsible  wins till now  177  out of  342
# playing game  342  with s =  superordinated, status? = Won at  superordinated  wins till now  178  out of  343
# playing game  343  with s =  gardia, status? = Won at  gardia  wins till now  179  out of  344
# playing game  344  with s =  excuseful, status? = Lost at  e__useful  wins till now  179  out of  345
# playing game  345  with s =  ascarid, status? = Won at  ascarid  wins till now  180  out of  346
# playing game  346  with s =  timberwright, status? = Won at  timberwright  wins till now  181  out of  347
# playing game  347  with s =  weftknit, status? = Lost at  _e___ni_  wins till now  181  out of  348
# playing game  348  with s =  wisevaliant, status? = Won at  wisevaliant  wins till now  182  out of  349
# playing game  349  with s =  lipacidemia, status? = Won at  lipacidemia  wins till now  183  out of  350
# playing game  350  with s =  medisection, status? = Won at  medisection  wins till now  184  out of  351
# playing game  351  with s =  vyase, status? = Lost at  __ase  wins till now  184  out of  352
# playing game  352  with s =  bungs, status? = Lost at  _ungs  wins till now  184  out of  353
# playing game  353  with s =  twelfthnight, status? = Won at  twelfthnight  wins till now  185  out of  354
# playing game  354  with s =  semimythically, status? = Won at  semimythically  wins till now  186  out of  355
# playing game  355  with s =  taconic, status? = Won at  taconic  wins till now  187  out of  356
# playing game  356  with s =  monosome, status? = Won at  monosome  wins till now  188  out of  357
# playing game  357  with s =  senseconfusing, status? = Won at  senseconfusing  wins till now  189  out of  358
# playing game  358  with s =  babbishly, status? = Won at  babbishly  wins till now  190  out of  359
# playing game  359  with s =  shopwindow, status? = Lost at  __o__in_o_  wins till now  190  out of  360
# playing game  360  with s =  oof, status? = Lost at  oo_  wins till now  190  out of  361
# playing game  361  with s =  treeembowered, status? = Won at  treeembowered  wins till now  191  out of  362
# playing game  362  with s =  reenroll, status? = Won at  reenroll  wins till now  192  out of  363
# playing game  363  with s =  solidbrowed, status? = Won at  solidbrowed  wins till now  193  out of  364
# playing game  364  with s =  pilocereus, status? = Lost at  __lo_ere_s  wins till now  193  out of  365
# playing game  365  with s =  temporization, status? = Won at  temporization  wins till now  194  out of  366
# playing game  366  with s =  menhaden, status? = Lost at  _en_aden  wins till now  194  out of  367
# playing game  367  with s =  steelboy, status? = Lost at  steel___  wins till now  194  out of  368
# playing game  368  with s =  oneirology, status? = Won at  oneirology  wins till now  195  out of  369
# playing game  369  with s =  gossoons, status? = Lost at  _ossoons  wins till now  195  out of  370
# playing game  370  with s =  ferrara, status? = Won at  ferrara  wins till now  196  out of  371
# playing game  371  with s =  frowstiest, status? = Won at  frowstiest  wins till now  197  out of  372
# playing game  372  with s =  inthralling, status? = Won at  inthralling  wins till now  198  out of  373
# playing game  373  with s =  grainger, status? = Won at  grainger  wins till now  199  out of  374
# playing game  374  with s =  urethrorrhoea, status? = Won at  urethrorrhoea  wins till now  200  out of  375
# playing game  375  with s =  introrse, status? = Won at  introrse  wins till now  201  out of  376
# playing game  376  with s =  untarnishedness, status? = Won at  untarnishedness  wins till now  202  out of  377
# playing game  377  with s =  arboral, status? = Lost at  ar_oral  wins till now  202  out of  378
# playing game  378  with s =  thigmotropic, status? = Won at  thigmotropic  wins till now  203  out of  379
# playing game  379  with s =  casabianca, status? = Won at  casabianca  wins till now  204  out of  380
# playing game  380  with s =  rollman, status? = Lost at  _ollman  wins till now  204  out of  381
# playing game  381  with s =  corrects, status? = Won at  corrects  wins till now  205  out of  382
# playing game  382  with s =  unschooled, status? = Won at  unschooled  wins till now  206  out of  383
# playing game  383  with s =  culiciform, status? = Won at  culiciform  wins till now  207  out of  384
# playing game  384  with s =  inheritress, status? = Won at  inheritress  wins till now  208  out of  385
# playing game  385  with s =  outlasts, status? = Won at  outlasts  wins till now  209  out of  386
# playing game  386  with s =  halfcivilly, status? = Won at  halfcivilly  wins till now  210  out of  387
# playing game  387  with s =  cosies, status? = Lost at  _osies  wins till now  210  out of  388
# playing game  388  with s =  orthopaedia, status? = Won at  orthopaedia  wins till now  211  out of  389
# playing game  389  with s =  egon, status? = Lost at  e_on  wins till now  211  out of  390
# playing game  390  with s =  trichopterygidae, status? = Won at  trichopterygidae  wins till now  212  out of  391
# playing game  391  with s =  carpetknight, status? = Won at  carpetknight  wins till now  213  out of  392
# playing game  392  with s =  upsydaisy, status? = Lost at  __s__ais_  wins till now  213  out of  393
# playing game  393  with s =  molpe, status? = Lost at  _olpe  wins till now  213  out of  394
# playing game  394  with s =  geohydrology, status? = Won at  geohydrology  wins till now  214  out of  395
# playing game  395  with s =  varro, status? = Lost at  _arr_  wins till now  214  out of  396
# playing game  396  with s =  danboro, status? = Lost at  _an__r_  wins till now  214  out of  397
# playing game  397  with s =  hyperope, status? = Lost at  __perope  wins till now  214  out of  398
# playing game  398  with s =  hyperlogically, status? = Won at  hyperlogically  wins till now  215  out of  399
# playing game  399  with s =  bilboas, status? = Won at  bilboas  wins till now  216  out of  400
# playing game  400  with s =  malaga, status? = Lost at  mala_a  wins till now  216  out of  401
# playing game  401  with s =  phyllaries, status? = Won at  phyllaries  wins till now  217  out of  402
# playing game  402  with s =  gliddery, status? = Lost at  gli__ery  wins till now  217  out of  403
# playing game  403  with s =  triodontes, status? = Won at  triodontes  wins till now  218  out of  404
# playing game  404  with s =  glasscutter, status? = Won at  glasscutter  wins till now  219  out of  405
# playing game  405  with s =  rux, status? = Lost at  _u_  wins till now  219  out of  406
# playing game  406  with s =  respelled, status? = Won at  respelled  wins till now  220  out of  407
# playing game  407  with s =  predependence, status? = Won at  predependence  wins till now  221  out of  408
# playing game  408  with s =  coltsfoots, status? = Lost at  _o__s_oo_s  wins till now  221  out of  409
# playing game  409  with s =  hyphenates, status? = Lost at  ____enates  wins till now  221  out of  410
# playing game  410  with s =  fatigue, status? = Lost at  _ati___  wins till now  221  out of  411
# playing game  411  with s =  trigonic, status? = Won at  trigonic  wins till now  222  out of  412
# playing game  412  with s =  isologues, status? = Won at  isologues  wins till now  223  out of  413
# playing game  413  with s =  pearlet, status? = Won at  pearlet  wins till now  224  out of  414
# playing game  414  with s =  abies, status? = Lost at  a_ies  wins till now  224  out of  415
# playing game  415  with s =  enlacing, status? = Lost at  enla_ing  wins till now  224  out of  416
# playing game  416  with s =  wilmington, status? = Lost at  _il_ington  wins till now  224  out of  417
# playing game  417  with s =  acetylcholine, status? = Won at  acetylcholine  wins till now  225  out of  418
# playing game  418  with s =  melisseus, status? = Won at  melisseus  wins till now  226  out of  419
# playing game  419  with s =  notepad, status? = Won at  notepad  wins till now  227  out of  420
# playing game  420  with s =  javer, status? = Lost at  _a_er  wins till now  227  out of  421
# playing game  421  with s =  unperceived, status? = Won at  unperceived  wins till now  228  out of  422
# playing game  422  with s =  sheff, status? = Lost at  she__  wins till now  228  out of  423
# playing game  423  with s =  papyral, status? = Lost at  _a__ral  wins till now  228  out of  424
# playing game  424  with s =  schefferite, status? = Lost at  sche__erite  wins till now  228  out of  425
# playing game  425  with s =  bigaroons, status? = Lost at  _i_aroons  wins till now  228  out of  426
# playing game  426  with s =  gastrostomies, status? = Won at  gastrostomies  wins till now  229  out of  427
# playing game  427  with s =  genuflecting, status? = Won at  genuflecting  wins till now  230  out of  428
# playing game  428  with s =  sussexite, status? = Lost at  ____e_ite  wins till now  230  out of  429
# playing game  429  with s =  stalagmite, status? = Won at  stalagmite  wins till now  231  out of  430
# playing game  430  with s =  retma, status? = Lost at  ret_a  wins till now  231  out of  431
# playing game  431  with s =  nomismata, status? = Won at  nomismata  wins till now  232  out of  432
# playing game  432  with s =  dishouse, status? = Lost at  dis___se  wins till now  232  out of  433
# playing game  433  with s =  toiletries, status? = Lost at  t_i_etries  wins till now  232  out of  434
# playing game  434  with s =  begonia, status? = Lost at  ___onia  wins till now  232  out of  435
# playing game  435  with s =  subserviency, status? = Won at  subserviency  wins till now  233  out of  436
# playing game  436  with s =  feminist, status? = Won at  feminist  wins till now  234  out of  437
# playing game  437  with s =  redefining, status? = Won at  redefining  wins till now  235  out of  438
# playing game  438  with s =  skatings, status? = Lost at  s_atings  wins till now  235  out of  439
# playing game  439  with s =  signifies, status? = Lost at  si__i_ies  wins till now  235  out of  440
# playing game  440  with s =  shortcoat, status? = Won at  shortcoat  wins till now  236  out of  441
# playing game  441  with s =  biscanism, status? = Lost at  _iscanism  wins till now  236  out of  442
# playing game  442  with s =  gelatigenous, status? = Won at  gelatigenous  wins till now  237  out of  443
# playing game  443  with s =  frigga, status? = Lost at  _ri__a  wins till now  237  out of  444
# playing game  444  with s =  outtear, status? = Lost at  __ttear  wins till now  237  out of  445
# playing game  445  with s =  bilek, status? = Lost at  __le_  wins till now  237  out of  446
# playing game  446  with s =  tannase, status? = Lost at  tanna_e  wins till now  237  out of  447
# playing game  447  with s =  disaligned, status? = Won at  disaligned  wins till now  238  out of  448
# playing game  448  with s =  upflare, status? = Lost at  ___la_e  wins till now  238  out of  449
# playing game  449  with s =  insemination, status? = Won at  insemination  wins till now  239  out of  450
# playing game  450  with s =  upheld, status? = Lost at  ___eld  wins till now  239  out of  451
# playing game  451  with s =  cycloplegia, status? = Won at  cycloplegia  wins till now  240  out of  452
# playing game  452  with s =  planirostal, status? = Won at  planirostal  wins till now  241  out of  453
# playing game  453  with s =  crossgrained, status? = Won at  crossgrained  wins till now  242  out of  454
# playing game  454  with s =  polysulphuration, status? = Won at  polysulphuration  wins till now  243  out of  455
# playing game  455  with s =  irgael, status? = Lost at  ir_ael  wins till now  243  out of  456
# playing game  456  with s =  nonreputably, status? = Won at  nonreputably  wins till now  244  out of  457
# playing game  457  with s =  nonattendance, status? = Won at  nonattendance  wins till now  245  out of  458
# playing game  458  with s =  fleurdelys, status? = Lost at  fleurdel_s  wins till now  245  out of  459
# playing game  459  with s =  twiceencountered, status? = Won at  twiceencountered  wins till now  246  out of  460
# playing game  460  with s =  inserted, status? = Won at  inserted  wins till now  247  out of  461
# playing game  461  with s =  mayed, status? = Lost at  _a___  wins till now  247  out of  462
# playing game  462  with s =  pearlescence, status? = Won at  pearlescence  wins till now  248  out of  463
# playing game  463  with s =  resummonable, status? = Won at  resummonable  wins till now  249  out of  464
# playing game  464  with s =  deutobromide, status? = Lost at  _e_t_____i_e  wins till now  249  out of  465
# playing game  465  with s =  whodunnit, status? = Lost at  __o_unnit  wins till now  249  out of  466
# playing game  466  with s =  gershonite, status? = Lost at  _ershonite  wins till now  249  out of  467
# playing game  467  with s =  sharpeared, status? = Won at  sharpeared  wins till now  250  out of  468
# playing game  468  with s =  versative, status? = Won at  versative  wins till now  251  out of  469
# playing game  469  with s =  oscillariaceae, status? = Won at  oscillariaceae  wins till now  252  out of  470
# playing game  470  with s =  ozonizing, status? = Won at  ozonizing  wins till now  253  out of  471
# playing game  471  with s =  headpan, status? = Lost at  head_an  wins till now  253  out of  472
# playing game  472  with s =  photojournalists, status? = Won at  photojournalists  wins till now  254  out of  473
# playing game  473  with s =  torment, status? = Won at  torment  wins till now  255  out of  474
# ...
# playing game  844  with s =  peacham, status? = Lost at  peacha_  wins till now  449  out of  845
# playing game  845  with s =  verily, status? = Lost at  ver___  wins till now  449  out of  846
# playing game  846  with s =  ampulla, status? = Won at  ampulla  wins till now  450  out of  847
# playing game  847  with s =  amati, status? = Won at  amati  wins till now  451  out of  848
# playing game  848  with s =  horsefly, status? = Won at  horsefly  wins till now  452  out of  849
# playing game  849  with s =  sclerema, status? = Lost at  sclere_a  wins till now  452  out of  850
# playing game  850  with s =  superpatriotically, status? = Won at  superpatriotically  wins till now  453  out of  851
# playing game  851  with s =  oniomaniac, status? = Won at  oniomaniac  wins till now  454  out of  852
# playing game  852  with s =  scouress, status? = Lost at  s___ress  wins till now  454  out of  853
# playing game  853  with s =  unheaved, status? = Won at  unheaved  wins till now  455  out of  854
# playing game  854  with s =  unluminescent, status? = Won at  unluminescent  wins till now  456  out of  855
# playing game  855  with s =  muckrakes, status? = Lost at  __c_ra_es  wins till now  456  out of  856
# playing game  856  with s =  kinkcough, status? = Lost at  _in____g_  wins till now  456  out of  857
# playing game  857  with s =  slug, status? = Lost at  s_u_  wins till now  456  out of  858
# playing game  858  with s =  sent, status? = Won at  sent  wins till now  457  out of  859
# playing game  859  with s =  symptomatic, status? = Won at  symptomatic  wins till now  458  out of  860
# playing game  860  with s =  fashionative, status? = Won at  fashionative  wins till now  459  out of  861
# playing game  861  with s =  dextroamphetamine, status? = Won at  dextroamphetamine  wins till now  460  out of  862
# playing game  862  with s =  tempestuousness, status? = Won at  tempestuousness  wins till now  461  out of  863
# playing game  863  with s =  lupi, status? = Lost at  _u_i  wins till now  461  out of  864
# playing game  864  with s =  scowbanker, status? = Lost at  _c___anker  wins till now  461  out of  865
# playing game  865  with s =  kominuter, status? = Lost at  _ominuter  wins till now  461  out of  866
# playing game  866  with s =  furthersome, status? = Lost at  __r__ersome  wins till now  461  out of  867
# playing game  867  with s =  ambulation, status? = Won at  ambulation  wins till now  462  out of  868
# playing game  868  with s =  dependably, status? = Won at  dependably  wins till now  463  out of  869
# playing game  869  with s =  chaudmelle, status? = Lost at  cha__melle  wins till now  463  out of  870
# playing game  870  with s =  mccabe, status? = Lost at  ___a_e  wins till now  463  out of  871
# playing game  871  with s =  ignition, status? = Won at  ignition  wins till now  464  out of  872
# playing game  872  with s =  acceptilating, status? = Won at  acceptilating  wins till now  465  out of  873
# playing game  873  with s =  kirkby, status? = Lost at  _ir___  wins till now  465  out of  874
# playing game  874  with s =  whiffleries, status? = Lost at  __i__leries  wins till now  465  out of  875
# playing game  875  with s =  unfluffed, status? = Lost at  _n_l___ed  wins till now  465  out of  876
# playing game  876  with s =  plainsboro, status? = Won at  plainsboro  wins till now  466  out of  877
# playing game  877  with s =  telestereoscope, status? = Won at  telestereoscope  wins till now  467  out of  878
# playing game  878  with s =  extravagate, status? = Won at  extravagate  wins till now  468  out of  879
# playing game  879  with s =  peroxidase, status? = Won at  peroxidase  wins till now  469  out of  880
# playing game  880  with s =  lamberton, status? = Won at  lamberton  wins till now  470  out of  881
# playing game  881  with s =  tallero, status? = Won at  tallero  wins till now  471  out of  882
# playing game  882  with s =  outwitted, status? = Won at  outwitted  wins till now  472  out of  883
# playing game  883  with s =  jestee, status? = Lost at  _estee  wins till now  472  out of  884
# playing game  884  with s =  isogeothermic, status? = Won at  isogeothermic  wins till now  473  out of  885
# playing game  885  with s =  unlade, status? = Lost at  un_a_e  wins till now  473  out of  886
# playing game  886  with s =  freddy, status? = Lost at  fre___  wins till now  473  out of  887
# playing game  887  with s =  dunaj, status? = Lost at  __na_  wins till now  473  out of  888
# playing game  888  with s =  trailerload, status? = Won at  trailerload  wins till now  474  out of  889
# playing game  889  with s =  propretorial, status? = Won at  propretorial  wins till now  475  out of  890
# playing game  890  with s =  intersubsistence, status? = Won at  intersubsistence  wins till now  476  out of  891
# playing game  891  with s =  unexclaiming, status? = Lost at  _ne__lai_ing  wins till now  476  out of  892
# playing game  892  with s =  portrayals, status? = Lost at  portra_a__  wins till now  476  out of  893
# playing game  893  with s =  millimicron, status? = Won at  millimicron  wins till now  477  out of  894
# playing game  894  with s =  socmen, status? = Lost at  so__en  wins till now  477  out of  895
# playing game  895  with s =  gyrated, status? = Won at  gyrated  wins till now  478  out of  896
# playing game  896  with s =  phrasey, status? = Lost at  phrase_  wins till now  478  out of  897
# playing game  897  with s =  capelin, status? = Won at  capelin  wins till now  479  out of  898
# playing game  898  with s =  uvulitises, status? = Lost at  u_ulitises  wins till now  479  out of  899
# playing game  899  with s =  josee, status? = Lost at  __see  wins till now  479  out of  900
# playing game  900  with s =  perhaps, status? = Lost at  per_ap_  wins till now  479  out of  901
# playing game  901  with s =  dartre, status? = Lost at  _artre  wins till now  479  out of  902
# playing game  902  with s =  yauds, status? = Lost at  _au_s  wins till now  479  out of  903
# playing game  903  with s =  vignettes, status? = Won at  vignettes  wins till now  480  out of  904
# playing game  904  with s =  museum, status? = Won at  museum  wins till now  481  out of  905
# playing game  905  with s =  sunman, status? = Lost at  _unman  wins till now  481  out of  906
# playing game  906  with s =  verbolatry, status? = Lost at  _erbolatry  wins till now  481  out of  907
# playing game  907  with s =  interleaf, status? = Won at  interleaf  wins till now  482  out of  908
# playing game  908  with s =  almsmoney, status? = Won at  almsmoney  wins till now  483  out of  909
# playing game  909  with s =  legatorial, status? = Won at  legatorial  wins till now  484  out of  910
# playing game  910  with s =  vellosine, status? = Lost at  _ell__ine  wins till now  484  out of  911
# playing game  911  with s =  nonabridgable, status? = Lost at  nonabrid_able  wins till now  484  out of  912
# playing game  912  with s =  furan, status? = Lost at  __ran  wins till now  484  out of  913
# playing game  913  with s =  quartes, status? = Lost at  __ar_es  wins till now  484  out of  914
# playing game  914  with s =  uncorpulent, status? = Won at  uncorpulent  wins till now  485  out of  915
# playing game  915  with s =  imperfectious, status? = Won at  imperfectious  wins till now  486  out of  916
# playing game  916  with s =  macaroons, status? = Won at  macaroons  wins till now  487  out of  917
# playing game  917  with s =  tapajo, status? = Lost at  tapa__  wins till now  487  out of  918
# playing game  918  with s =  aestive, status? = Won at  aestive  wins till now  488  out of  919
# playing game  919  with s =  washin, status? = Won at  washin  wins till now  489  out of  920
# playing game  920  with s =  adenography, status? = Won at  adenography  wins till now  490  out of  921
# playing game  921  with s =  economese, status? = Won at  economese  wins till now  491  out of  922
# playing game  922  with s =  stiffneck, status? = Won at  stiffneck  wins till now  492  out of  923
# playing game  923  with s =  theocrasies, status? = Won at  theocrasies  wins till now  493  out of  924
# playing game  924  with s =  siluroidei, status? = Won at  siluroidei  wins till now  494  out of  925
# playing game  925  with s =  agsam, status? = Lost at  a_sa_  wins till now  494  out of  926
# playing game  926  with s =  scind, status? = Lost at  s_in_  wins till now  494  out of  927
# playing game  927  with s =  abridgers, status? = Lost at  a_r_dgers  wins till now  494  out of  928
# playing game  928  with s =  minting, status? = Lost at  _inting  wins till now  494  out of  929
# playing game  929  with s =  unconcessible, status? = Won at  unconcessible  wins till now  495  out of  930
# playing game  930  with s =  subconcavely, status? = Lost at  s______avely  wins till now  495  out of  931
# playing game  931  with s =  elvanitic, status? = Won at  elvanitic  wins till now  496  out of  932
# playing game  932  with s =  independents, status? = Won at  independents  wins till now  497  out of  933
# playing game  933  with s =  unligatured, status? = Won at  unligatured  wins till now  498  out of  934
# playing game  934  with s =  acridophagus, status? = Lost at  acri__p_a___  wins till now  498  out of  935
# playing game  935  with s =  stammerwort, status? = Won at  stammerwort  wins till now  499  out of  936
# playing game  936  with s =  splenorrhaphy, status? = Won at  splenorrhaphy  wins till now  500  out of  937
# playing game  937  with s =  les, status? = Won at  les  wins till now  501  out of  938
# playing game  938  with s =  chthonophagy, status? = Won at  chthonophagy  wins till now  502  out of  939
# playing game  939  with s =  surfeiting, status? = Won at  surfeiting  wins till now  503  out of  940
# playing game  940  with s =  paleobotanical, status? = Won at  paleobotanical  wins till now  504  out of  941
# playing game  941  with s =  flatshouldered, status? = Won at  flatshouldered  wins till now  505  out of  942
# playing game  942  with s =  neocomian, status? = Lost at  n__c__ian  wins till now  505  out of  943
# playing game  943  with s =  scutching, status? = Lost at  s__t__ing  wins till now  505  out of  944
# playing game  944  with s =  goldenmouth, status? = Lost at  golden_o_th  wins till now  505  out of  945
# playing game  945  with s =  trailiness, status? = Won at  trailiness  wins till now  506  out of  946
# playing game  946  with s =  looser, status? = Won at  looser  wins till now  507  out of  947
# playing game  947  with s =  sharecroppers, status? = Won at  sharecroppers  wins till now  508  out of  948
# playing game  948  with s =  rizzo, status? = Lost at  ri___  wins till now  508  out of  949
# playing game  949  with s =  outmate, status? = Won at  outmate  wins till now  509  out of  950
# playing game  950  with s =  jinglers, status? = Lost at  ____lers  wins till now  509  out of  951
# playing game  951  with s =  surinam, status? = Lost at  s_rinam  wins till now  509  out of  952
# playing game  952  with s =  caprifoliaceae, status? = Won at  caprifoliaceae  wins till now  510  out of  953
# playing game  953  with s =  angloirishism, status? = Won at  angloirishism  wins till now  511  out of  954
# playing game  954  with s =  sarcoglia, status? = Lost at  sarco_l_a  wins till now  511  out of  955
# playing game  955  with s =  ofdoor, status? = Won at  ofdoor  wins till now  512  out of  956
# playing game  956  with s =  circumvents, status? = Won at  circumvents  wins till now  513  out of  957
# playing game  957  with s =  stiffplate, status? = Lost at  sti__plate  wins till now  513  out of  958
# playing game  958  with s =  campanologist, status? = Won at  campanologist  wins till now  514  out of  959
# playing game  959  with s =  ternar, status? = Won at  ternar  wins till now  515  out of  960
# playing game  960  with s =  antirabies, status? = Won at  antirabies  wins till now  516  out of  961
# playing game  961  with s =  liquidless, status? = Lost at  li__idless  wins till now  516  out of  962
# playing game  962  with s =  regressiveness, status? = Won at  regressiveness  wins till now  517  out of  963
# playing game  963  with s =  thickpiled, status? = Won at  thickpiled  wins till now  518  out of  964
# playing game  964  with s =  unwilful, status? = Won at  unwilful  wins till now  519  out of  965
# playing game  965  with s =  anounou, status? = Lost at  a______  wins till now  519  out of  966
# playing game  966  with s =  pseudociceronian, status? = Won at  pseudociceronian  wins till now  520  out of  967
# playing game  967  with s =  teleportation, status? = Won at  teleportation  wins till now  521  out of  968
# playing game  968  with s =  yabble, status? = Lost at  _abble  wins till now  521  out of  969
# playing game  969  with s =  semipneumatical, status? = Won at  semipneumatical  wins till now  522  out of  970
# playing game  970  with s =  enteroneuritis, status? = Won at  enteroneuritis  wins till now  523  out of  971
# playing game  971  with s =  nonconvertibly, status? = Won at  nonconvertibly  wins till now  524  out of  972
# playing game  972  with s =  supersolar, status? = Won at  supersolar  wins till now  525  out of  973
# playing game  973  with s =  surmaster, status? = Won at  surmaster  wins till now  526  out of  974
# playing game  974  with s =  benchley, status? = Lost at  _en___e_  wins till now  526  out of  975
# playing game  975  with s =  slumming, status? = Lost at  sl___ing  wins till now  526  out of  976
# playing game  976  with s =  quasivalidly, status? = Won at  quasivalidly  wins till now  527  out of  977
# playing game  977  with s =  unerrancy, status? = Won at  unerrancy  wins till now  528  out of  978
# playing game  978  with s =  sobbingly, status? = Lost at  so__ingly  wins till now  528  out of  979
# playing game  979  with s =  ranier, status? = Won at  ranier  wins till now  529  out of  980
# playing game  980  with s =  blois, status? = Lost at  _lois  wins till now  529  out of  981
# playing game  981  with s =  gradgrindian, status? = Won at  gradgrindian  wins till now  530  out of  982
# playing game  982  with s =  misrating, status? = Lost at  _i_rating  wins till now  530  out of  983
# playing game  983  with s =  merls, status? = Lost at  _er_s  wins till now  530  out of  984
# playing game  984  with s =  helyn, status? = Lost at  _el_n  wins till now  530  out of  985
# playing game  985  with s =  laches, status? = Won at  laches  wins till now  531  out of  986
# playing game  986  with s =  hazzanut, status? = Lost at  _a__an_t  wins till now  531  out of  987
# playing game  987  with s =  technological, status? = Won at  technological  wins till now  532  out of  988
# playing game  988  with s =  laddikie, status? = Lost at  la______  wins till now  532  out of  989
# playing game  989  with s =  unapposable, status? = Won at  unapposable  wins till now  533  out of  990
# playing game  990  with s =  datebook, status? = Lost at  _at_____  wins till now  533  out of  991
# playing game  991  with s =  thymeleaved, status? = Lost at  t___eleaved  wins till now  533  out of  992
# playing game  992  with s =  avondbloem, status? = Lost at  a_ond_loem  wins till now  533  out of  993
# playing game  993  with s =  aliquant, status? = Won at  aliquant  wins till now  534  out of  994
# playing game  994  with s =  duetted, status? = Lost at  d_etted  wins till now  534  out of  995
# playing game  995  with s =  rims, status? = Lost at  ri_s  wins till now  534  out of  996
# playing game  996  with s =  cholepoietic, status? = Won at  cholepoietic  wins till now  535  out of  997
# playing game  997  with s =  scleroparei, status? = Won at  scleroparei  wins till now  536  out of  998
# playing game  998  with s =  flatway, status? = Won at  flatway  wins till now  537  out of  999
# playing game  999  with s =  wishbone, status? = Lost at  _i_hbone  wins till now  537  out of  1000

# %%
failedStrings
# Out:
# ['_or_le',
#  '_inst',
#  'matat_a',
#  '_istoriette',
#  'suns_art',
#  '_a_e',
#  '_ail_arder',
#  '_i_etoot_ed',
#  '_rea_s',
#  'peter_ort',
#  'es_i',
#  'tri_lyphal',
#  '_i_a',
#  'es_a_le',
#  'slo__ing',
#  'no__ea',
#  'over_i_es',
#  'ca_is',
#  '_e_en___',
#  're_i_iction',
#  '_itchellsburg',
#  'thousande_ed',
#  '_ini_orous',
#  't_ro_ean',
#  'reele_ation',
#  '_a__erproo_',
#  '_os__onon_',
#  '_u____',
#  '_ar_er',
#  '_rolit_ology',
#  'se_',
#  '_urio',
#  'basen_i',
#  'shortt_isted',
#  'overi__i_ing',
#  '_ele_',
#  '_u_a_',
#  'canni_ality',
#  '__in__',
#  'ta_ilelt',
#  '_arnished',
#  '_ar_',
#  'una__licting',
#  'coach_uilt',
#  '_alary',
#  '_i_roo_',
#  '__o___',
#  '_e__eathed',
#  'e_a_',
#  '_ar_ari_es',
#  'e__e_erally',
#  '_urtures',
#  '_e_len',
#  '_allmine',
#  'su__u__ers',
#  '_o_oc_cle',
#  '_ull_ro__',
#  '_estro_ed',
#  'broo_land',
#  '_ur_ier',
#  'sla__ed',
#  '_la__ulated',
#  'cana_ol',
#  '_oundage',
#  'guaia_ums',
#  '_henic',
#  '____es',
#  '__si_is',
#  '_uttles',
#  'en__erably',
#  'in_uisitively',
#  'ashie_',
#  '_er_er_a_e',
#  '_atesville',
#  'creo_ol',
#  'sta___a__',
#  'e_ulosis',
#  '_i___orn',
#  '_li__s__al_',
#  'appro_imating',
#  '_inn_',
#  'de_e',
#  '__ann',
#  'al_icant',
#  's_u__s',
#  '_en_indu_ine',
#  '_i__',
#  'inter_eined',
#  '___lellan_',
#  'mero_oa',
#  'un_rin_led',
#  '__oe',
#  'a__isar',
#  'de_ouringness',
#  '__idable',
#  '_ra__it',
#  'haemato__te',
#  '_ol__',
#  '__o___e',
#  'a____icating',
#  '_a___',
#  '_a__',
#  'si_e_i__s',
#  '_u__alli',
#  '_inai_re']

# %%
import gym
from gym import spaces

class CustomEnv(gym.Env):
    def __init__(self):
        super(CustomEnv, self).__init__()
        self.action_space = spaces.Discrete(26); #26 letters in the alphabet that are our options
        
        pass
